# %% [markdown]
# # Trabalhando com eixos

# %% [markdown]
# ## Gráfico de linhas

# %%
import matplotlib.pyplot as plt

meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]

# %%
fig, ax = plt.subplots()
ax.plot(meses, vendas)

ax.set_ylabel('Vendas')
ax.set_xlabel('Meses')
ax.set_title('Vendas 2025')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Gráfico de barras

# %%
import matplotlib.pyplot as plt

produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

# %%
fig, ax = plt.subplots()

ax.bar(produtos, quantidades)

ax.set_ylabel('quantidades')
ax.set_xlabel('Produtos')
ax.set_title('Estoque 2025')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Gráfico de pizza

# %%
categorias = ['Eletrônicos', 'Roupas', 'Alimentos', 'Livros']
quantidades = [45, 30, 15, 10]
destaque = [0.05, 0, 0, 0]  # destacar a primeira fatia

# %%
fig, ax = plt.subplots()

ax.pie(quantidades, labels = categorias, explode = destaque, autopct = '%.1f')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Gráfico de barras empilhadas

# %%
anos = [2018, 2019, 2020, 2021]
vendas_online = [5, 10, 15, 20]
vendas_loja = [10, 8, 6, 4]

# %%
fig, ax = plt.subplots()

ax.bar(anos, vendas_online, label = 'Online')
ax.bar(anos, vendas_loja, bottom = vendas_online, label = 'Loja')

ax.set_ylabel('quantidade vendida')
ax.set_xlabel('Anos')
ax.set_title('Vendas Online X Vendas loja física')

ax.legend()
ax.set_xticks(anos)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
