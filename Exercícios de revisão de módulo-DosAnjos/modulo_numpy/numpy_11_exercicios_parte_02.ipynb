# %% [markdown]
# ## Exercício
#
# Você é um analista de dados em uma empresa e conduziu uma pesquisa de satisfação do cliente durante uma semana. Você perguntou as clientes para classificar seu nível de satisfação com o serviço ao cliente em uma escala de 0 a 10. Você coletou respostas de 30 clientes por dia durante 7 dias, resultando em um total de 210 respostas.
#
# No entanto, os dados que você recebeu estão em um array 1D de 210 elementos. Reorganize os dados de forma a ter as respostas por dia e faça uma análise descritiva básica, calculando a média geral de satisfação e a média diária.

# %%
import numpy as np

# considere os seguintes dados aleatórios como início
rng = np.random.default_rng(seed=42)
respostas = rng.integers(low=0, high=10, size=210, endpoint=True)

avaliacao_dia = respostas.reshape(7, 30)

def media_geral(avaliações):
    mg = avaliações.mean()
    return mg

def media_por_dia(avaliações):
    mpd = avaliações.mean(axis = 1)
    return mpd

print(f"Em média as avaliações geram uma nota {media_geral(avaliacao_dia):.2f}")

for dia, avaliacao in enumerate(media_por_dia(avaliacao_dia)):
    print(f"No dia {dia}, a média de avaliações foi {avaliacao:.2f}")
# Out:
# Em média as avaliações geram uma nota 5.15
# No dia 0, a média de avaliações foi 5.50
# No dia 1, a média de avaliações foi 5.07
# No dia 2, a média de avaliações foi 5.37
# No dia 3, a média de avaliações foi 5.10
# No dia 4, a média de avaliações foi 4.97
# No dia 5, a média de avaliações foi 5.00
# No dia 6, a média de avaliações foi 5.03
