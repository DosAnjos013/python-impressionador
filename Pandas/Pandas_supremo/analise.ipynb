# %%
import pandas as pd
import numpy as np

# %%
vendas = pd.read_csv(r'C:\Users\joa_o\Downloads\ESTRELA GESTAO EM INFORMATICA LTDA - Sistema (1).csv')
display(vendas.sample(20))
# Out:
#     Cod           Produto Custo un  Valor un Vendidos    Custo      Valor  \
# 10   44        X - SALADA  R$ 0,00  R$ 18,00   4.0000  R$ 0,00   R$ 72,00
# 94   44        X - SALADA  R$ 0,00  R$ 18,00  23.0000  R$ 0,00  R$ 414,00
# 31   44        X - SALADA  R$ 0,00  R$ 18,00   4.0000  R$ 0,00   R$ 72,00
# 176  45  X - SALADA DUPLO  R$ 0,00  R$ 25,00   1.0000  R$ 0,00   R$ 25,00
# 148  42       X - BURGUER  R$ 0,00  R$ 15,00  10.0000  R$ 0,00  R$ 150,00
# 27   44        X - SALADA  R$ 0,00  R$ 20,00   1.0000  R$ 0,00   R$ 20,00
# 16   50         X - BACON  R$ 0,00  R$ 25,00   2.0000  R$ 0,00   R$ 50,00
# 195  46           X - EGG  R$ 0,00  R$ 20,00   2.0000  R$ 0,00   R$ 40,00
# 170  50         X - BACON  R$ 0,00  R$ 25,00   3.0000  R$ 0,00   R$ 75,00
# 181  44        X - SALADA  R$ 0,00  R$ 18,00  31.0000  R$ 0,00  R$ 558,00
# 14   44        X - SALADA  R$ 0,00  R$ 18,00   4.0000  R$ 0,00   R$ 72,00
# 20   44        X - SALADA  R$ 0,00  R$ 18,00   1.0000  R$ 0,00   R$ 18,00
# ...
