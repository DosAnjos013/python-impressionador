# %% [markdown]
# Para isso, usaremos o parametro 'w' junto com o novo arquivo que estamos criando.
# aLém disso precisaremos abrir (função) e tambem fechar (metodo) o arquivo para que as alterações de fato sejam executadas.

# %%
arquivo = open('novo', 'w')

arquivo.write('Teste')

arquivo.close()
