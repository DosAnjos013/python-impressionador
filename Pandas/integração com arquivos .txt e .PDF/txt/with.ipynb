# %% [markdown]
# A estrutura with nos permite "resumir' um pouco o código. Com ela não será necessário usar o metodo close para fechar o arquivo txt.

# %%
with open('teste2.txt', 'w') as arquivo:
    arquivo.write('testando estrutura with')
    arquivo.write('fim do teste')
