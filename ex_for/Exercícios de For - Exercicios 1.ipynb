# %% [markdown]
# # Exercícios
#
# ## 1. Criando um Registro de Hóspedes
#
# Digamos que você está criando o sistema para registrar a chegada de hóspedes em um hotel. No hotel, os hóspedes podem ter quartos com 1, 2, 3 e 4 pessoas. Seu sistema deve conseguir:
#
# 1. Identificar quantas pessoas o hóspede que acabou de chegar vai ter no quarto (perguntando por meio de input)
# 2. De acordo com a quantidade de pessoas do hóspede, ele deve fazer um for para perguntar o cpf e o nome de cada pessoa, a fim de registrá-la no quarto (2 inputs para cada pessoa, 1 para o cpf e outro para o nome)
# 3. O seu programa então deve gerar uma lista com todas as pessoas que ficarão no quarto em que cada item dessa lista é o nome da pessoa e o cpf da pessoa, assim:

# %% [raw]
# quarto = [
#     ['João', 'cpf:00000000000'],
#     ['Julia', 'cpf:11111111111'],
#     ['Marcus', 'cpf:22222222222'],
#     ['Maria', 'cpf:33333333333'],
# ]

# %% [markdown]
# - Para simplificar, não vamos nos preocupar com possibilidades de "tentar colocar mais de 1 hóspede, digitar o cpf errado, etc. Nosso objetivo é treinar a criação de uma rotina de cadastro

# %%
qtd_hospedes =input("Qual quantidade de hospedes?: ") 
hospedes = []
verifica_qtd = True
while verifica_qtd == True:
    if qtd_hospedes.isnumeric() == True:
        if int(qtd_hospedes) <= 4:
            for i in range(int(qtd_hospedes)):
                cadastro = []
                nome = input("\nQual o nome do {}° hospede: ".format(i+1))
                cadastro.append(nome)
                cpf = input("\nDigite o CPF de {}: ".format(nome))
                cadastro.append(cpf)
                hospedes.append(cadastro.copy())
                cadastro.clear()
                verifica_qtd = False
        else:
            print("Não temos quartos para mais do que 4 pessoas!\nVamos tentar novamente!\n\n")
            qtd_hospedes = input("Qual a quantidade de hospedes?: ")
            verifica_qtd = True
    else:
        print("Você deve digitar apenas números!\nVamos tentar mais uma vez!\n")
        qtd_hospedes = input("Qual a quantidade de hospedes?: ")
        verifica_qtd = True

print ("\n")
for i in range(int(qtd_hospedes)):
    print(hospedes[i])
# Out:
# Qual quantidade de hospedes?:  a
# Você deve digitar apenas números!
# Vamos tentar mais uma vez!
# Qual a quantidade de hospedes?:  5
# Não temos quartos para mais do que 4 pessoas!
# Vamos tentar novamente!
# Qual a quantidade de hospedes?:  4
#
# Qual o nome do 1° hospede:  asdf
#
# Digite o CPF de asdf:  123
#
# Qual o nome do 2° hospede:  df
#
# Digite o CPF de df:  456
#
# Qual o nome do 3° hospede:  SDF
#
# Digite o CPF de SDF:  789
#
# Qual o nome do 4° hospede:  ASDG
#
# Digite o CPF de ASDG:  101112
# ['asdf', '123']
# ['df', '456']
# ['SDF', '789']
# ['ASDG', '101112']

# %% [markdown]
# ## 2. Análise de Vendas
#
# Nesse exercício vamos fazer uma "análise simples" de atingimento de Meta.
#
# Temos uma lista com os vendedores e os valores de vendas e queremos identificar (printar) quais os vendedores que bateram a meta e qual foi o valor que eles venderam.

# %%
meta = 10000
vendas = [
    ['João', 15000],
    ['Julia', 27000],
    ['Marcus', 9900],
    ['Maria', 3750],
    ['Ana', 10300],
    ['Alon', 7870],
]
bateram_meta = []
for i in range(len(vendas)):
    if int(vendas[i][1]) >= meta:
        bateram_meta.append(vendas[i])

print (bateram_meta)
# Out:
# [['João', 15000], ['Julia', 27000], ['Ana', 10300]]

# %% [markdown]
# ## 3. Comparação com Ano Anterior
#
# Digamos que você está analisando as vendas de produtos de um ecommerce e quer identificar quais produtos tiveram no ano de 2020 mais vendas do que no ano de 2019, para reportar isso para a diretoria.
#
# Sua resposta pode ser um print de cada produto, qual foi a venda de 2019, a venda de 2020 e o % de crescimento de 2020 para 2019.
#
# Lembrando, para calcular o % de crescimento de um produto de um ano para o outro, podemos fazer: (vendas_produto2020/vendas_produto2019 - 1)
#
# Dica: lembre do enumerate, ele pode facilitar seu "for"

# %%
produtos = ['iphone', 'galaxy', 'ipad', 'tv', 'máquina de café', 'kindle', 'geladeira', 'adega', 'notebook dell', 'notebook hp', 'notebook asus', 'microsoft surface', 'webcam', 'caixa de som', 'microfone', 'câmera canon']
vendas2019 = [558147,712350,573823,405252,718654,531580,973139,892292,422760,154753,887061,438508,237467,489705,328311,591120]
vendas2020 = [951642,244295,26964,787604,867660,78830,710331,646016,694913,539704,324831,667179,295633,725316,644622,994303]

for i, produto in enumerate(produtos):
    print("Produto: {}".format(produto))
    print("A quantidade de {} vendidos em 2019 foi: {} unidades".format(produto,vendas2019[i]))
    print("A quantidade de {} vendidos em 2020 foi: {} unidades".format(produto,vendas2020[i]))
    if vendas2020[i] > vendas2019[i]:
        crescimento = (vendas2020[i] / vendas2019[i] - 1) *100
        print("Crescimento: {:.2f}%".format(crescimento))
    else:
        print("Não houve aumento de vendas do produto!")
    print("-" * 60)
# Out:
# Produto: iphone
# A quantidade de iphone vendidos em 2019 foi: 558147 unidades
# A quantidade de iphone vendidos em 2020 foi: 951642 unidades
# Crescimento: 70.50%
# ------------------------------------------------------------
# Produto: galaxy
# A quantidade de galaxy vendidos em 2019 foi: 712350 unidades
# A quantidade de galaxy vendidos em 2020 foi: 244295 unidades
# Não houve aumento de vendas do produto!
# ------------------------------------------------------------
# Produto: ipad
# A quantidade de ipad vendidos em 2019 foi: 573823 unidades
# A quantidade de ipad vendidos em 2020 foi: 26964 unidades
# Não houve aumento de vendas do produto!
# ------------------------------------------------------------
# Produto: tv
# A quantidade de tv vendidos em 2019 foi: 405252 unidades
# A quantidade de tv vendidos em 2020 foi: 787604 unidades
# Crescimento: 94.35%
# ------------------------------------------------------------
# Produto: máquina de café
# ...
