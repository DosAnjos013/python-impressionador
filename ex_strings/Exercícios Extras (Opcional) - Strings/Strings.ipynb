# %% [markdown]
# # Strings
#
# <span style="color: red;"><b>Todos os exercícios são feitos partindo-se do pressuposto de que todas as entradas são dadas de forma correta. Casos limite não mencionados no enunciado não são abordados porque não fazem parte do exercício.</b></span>

# %% [markdown]
# #### 1. Tamanho de strings. Faça um programa que leia 2 strings e informe o conteúdo delas seguido do seu comprimento. Informe também se as duas strings possuem o mesmo comprimento e são iguais ou diferentes no conteúdo.
# <pre>
# Compara duas strings
# String 1: Brasil Hexa 2006
# String 2: Brasil! Hexa 2006!
# Tamanho de "Brasil Hexa 2006": 16 caracteres
# Tamanho de "Brasil! Hexa 2006!": 18 caracteres
# As duas strings são de tamanhos diferentes.
# As duas strings possuem conteúdo diferente.
# </pre>

# %%
s1 = input('Digite a 1° string: ')
s2 = input('Digite a 2° string: ')
print('A primeira string é: ', s1)
print('A segunda string é: ', s2)
print('A primeira string tem', len(s1), 'caracteres. A segunda string tem', len(s2), 'caracteres')
if s1 == s2:
    print('O conteúdo das Strings é idêntico!')
else:
    print('O conteudo das Strings é diferente!')
# Out:
# Digite a 1° string:  João
# Digite a 2° string:  joão
# A primeira string é:  João
# A segunda string é:  joão
# A primeira string tem 4 caracteres. A segunda string tem 4 caracteres
# O conteudo das Strings é diferente!

# %% [markdown]
# #### 2. Valida e corrige número de telefone. Faça um programa que leia um número de telefone, e corrija o número no caso deste conter somente 7 dígitos, acrescentando o '3' na frente. O usuário pode informar o número com ou sem o traço separador.
# <pre>
# Valida e corrige número de telefone
# Telefone: 461-0133
# Telefone possui 7 dígitos. Vou acrescentar o digito três na frente.
# Telefone corrigido sem formatação: 34610133
# Telefone corrigido com formatação: 3461-0133
# </pre>

# %%
tel = input('Digite o número de telefone: ')
tel = tel.strip()
tel = tel.replace(" ", "")
tel = tel.replace(".","")
tel = tel.replace("-","")
tel = tel.replace(",","")
verificador = False
while verificador == False:
    if len(tel) < 8:
        print("\nVocê digitou menos números do que deveria...")
        print("Vamos tentar mais uma vez, ok?")
        tel = input('Digite o número de telefone com 8 dígitos: ')
    elif len(tel) > 8:
        print("\nVocê digitou mais números do que deveria...\n")
        print("Vamos tentar mais uma vez, ok?")
        tel = input('Digite o número de telefone com 8 dígitos: ')
    else:
        verificador = True
        print(tel[:4],"-",tel[4:])
# Out:
# Digite o número de telefone:  123
# Você digitou menos números do que deveria...
#
# Vamos tentar mais uma vez, ok?
# Digite o número de telefone com 8 dígitos:  123456789
# Você digitou mais números do que deveria...
#
# Vamos tentar mais uma vez, ok?
# Digite o número de telefone com 8 dígitos:  12345678
# 1234 - 5678
