# %%
import pyodbc
import pandas as pd
print(pyodbc.drivers())
# Out:
# ['SQL Server', 'SQLite3 ODBC Driver', 'SQLite ODBC Driver', 'SQLite ODBC (UTF-8) Driver']

# %%
dados = ('DRIVER={SQLite3 ODBC Driver};SERVER=localhost;DATABASE=chinook.db')
conexao = pyodbc.connect(dados)
cursor = conexao.cursor()

# %%
cursor.execute('''
DELETE FROM albums WHERE Title = "Lira Rock"
''')

cursor.commit()

# %%
cursor.close()
conexao.close()
