# %%
import pandas as pd
import pyodbc
print(pyodbc.drivers())
# Out:
# ['SQL Server', 'SQLite3 ODBC Driver', 'SQLite ODBC Driver', 'SQLite ODBC (UTF-8) Driver']

# %%
connection_data = ('DRIVER={SQLite3 ODBC Driver};SERVER=localhost;DATABASE=chinook.db')

conexao = pyodbc.connect(connection_data)
cursor = conexao.cursor()

# %%
cursor.execute("""
UPDATE customers SET Email = 'joao@embraer.com.br' WHERE Email = 'luisg@embraer.com.br'
""")

cursor.commit()

# %%
cursor.close()
conexao.close()
